# %% [markdown]
# # Data Prep for Neo4j Import

# %% [markdown]
# ## 1. Load Data, Clean NaN Values, and Remove Unnecessary Columns

# %% [markdown]
# ### a. Scrap Position Group Keys from 247 Sports Website into dataframe

# %%
import neo4j
import pandas as pd
import numpy as np

from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests

# %%
from bs4 import BeautifulSoup

import requests

header = {'User-agent' : 'Mozilla/5.0 (Windows; U; Windows NT 5.1; de; rv:1.9.1.5) Gecko/20091102 Firefox/3.5.5'}

url = requests.get("https://247sports.com/Position/?year=2010&sport=Football", headers=header).text

soup = BeautifulSoup(url, 'html.parser')
table = soup.find('table', {'class': 'position_tbl'})

df_pos = pd.read_html(str(table))[0]

# %%
df_pos
# Out:
#        Sport                   Platoon  Position Group  \
# 0   Football        Football (Offense)     Quarterback
# 1   Football        Football (Offense)     Quarterback
# 2   Football        Football (Offense)     Quarterback
# 3   Football        Football (Offense)    Running Back
# 4   Football        Football (Offense)    Running Back
# 5   Football        Football (Offense)    Running Back
# 6   Football        Football (Offense)        Receiver
# 7   Football        Football (Offense)        Receiver
# 8   Football        Football (Offense)  Offensive Line
# 9   Football        Football (Offense)  Offensive Line
# 10  Football        Football (Offense)  Offensive Line
# 11  Football        Football (Offense)  Offensive Line
# 12  Football        Football (Defense)  Defensive Line
# 13  Football        Football (Defense)  Defensive Line
# 14  Football        Football (Defense)  Defensive Line
# 15  Football        Football (Defense)  Defensive Line
# 16  Football        Football (Defense)  Defensive Line
# 17  Football        Football (Defense)      Linebacker
# 18  Football        Football (Defense)      Linebacker
# 19  Football        Football (Defense)      Linebacker
# 20  Football        Football (Defense)  Defensive Back
# 21  Football        Football (Defense)  Defensive Back
# 22  Football  Football (Special Teams)   Special Teams
# 23  Football  Football (Special Teams)   Special Teams
# 24  Football  Football (Special Teams)   Special Teams
# 25  Football  Football (Special Teams)   Special Teams
# 26  Football  Football (Special Teams)   Special Teams
#
#                          Name Abbreviation  Start Year  End Year  \
# 0       Pro-Style Quarterback          PRO           0    2020.0
# 1     Dual-Threat Quarterback         DUAL           0    2020.0
# 2                 Quarterback           QB        2021       NaN
# 3            All Purpose Back          APB           0    2020.0
# 4                Running Back           RB           0       NaN
# 5                    Fullback           FB           0    2020.0
# 6               Wide Receiver           WR           0       NaN
# 7                   Tight End           TE           0       NaN
# 8            Offensive Tackle           OT           0       NaN
# 9             Offensive Guard           OG           0    2020.0
# 10                Center (FB)           OC           0    2020.0
# 11             Offensive Line          IOL        2021       NaN
# 12    Weak-Side Defensive End          WDE           0    2020.0
# 13  Strong-Side Defensive End          SDE           0    2020.0
# 14           Defensive Tackle           DT           0    2020.0
# 15                       Edge         Edge        2021       NaN
# 16             Defensive Line           DL        2021       NaN
# 17          Inside Linebacker          ILB           0    2020.0
# 18         Outside Linebacker          OLB           0    2020.0
# 19                 Linebacker           LB        2021       NaN
# 20                 Cornerback           CB           0       NaN
# 21                     Safety            S           0       NaN
# 22                    Athlete          ATH           0       NaN
# 23                     Kicker            K           0       NaN
# 24                     Punter            P           0       NaN
# 25               Long Snapper           LS           0       NaN
# 26                   Returner          RET           0       NaN
#
#                  Default Name  \
# 0       Pro-Style Quarterback
# 1     Dual-Threat Quarterback
# 2                 Quarterback
# 3            All Purpose Back
# 4                Running Back
# 5                    Fullback
# 6               Wide Receiver
# 7                   Tight End
# 8            Offensive Tackle
# 9             Offensive Guard
# 10                Center (FB)
# 11             Offensive Line
# 12    Weak-Side Defensive End
# 13  Strong-Side Defensive End
# 14           Defensive Tackle
# 15                       Edge
# 16             Defensive Line
# 17          Inside Linebacker
# 18         Outside Linebacker
# 19                 Linebacker
# 20                 Cornerback
# 21                     Safety
# 22                    Athlete
# 23                     Kicker
# 24                     Punter
# 25               Long Snapper
# 26                   Returner
#
#                                            Unnamed: 8
# 0   EditDelete More ▾ Player PositionsPlayer Sport...
# 1   EditDelete More ▾ Player PositionsPlayer Sport...
# 2   EditDelete More ▾ Player PositionsPlayer Sport...
# 3   EditDelete More ▾ Player PositionsPlayer Sport...
# 4   EditDelete More ▾ Player PositionsPlayer Sport...
# 5   EditDelete More ▾ Player PositionsPlayer Sport...
# 6   EditDelete More ▾ Player PositionsPlayer Sport...
# 7   EditDelete More ▾ Player PositionsPlayer Sport...
# 8   EditDelete More ▾ Player PositionsPlayer Sport...
# 9   EditDelete More ▾ Player PositionsPlayer Sport...
# 10  EditDelete More ▾ Player PositionsPlayer Sport...
# 11  EditDelete More ▾ Player PositionsPlayer Sport...
# 12  EditDelete More ▾ Player PositionsPlayer Sport...
# 13  EditDelete More ▾ Player PositionsPlayer Sport...
# 14  EditDelete More ▾ Player PositionsPlayer Sport...
# 15  EditDelete More ▾ Player PositionsPlayer Sport...
# 16  EditDelete More ▾ Player PositionsPlayer Sport...
# 17  EditDelete More ▾ Player PositionsPlayer Sport...
# 18  EditDelete More ▾ Player PositionsPlayer Sport...
# 19  EditDelete More ▾ Player PositionsPlayer Sport...
# 20  EditDelete More ▾ Player PositionsPlayer Sport...
# 21  EditDelete More ▾ Player PositionsPlayer Sport...
# 22  EditDelete More ▾ Player PositionsPlayer Sport...
# 23  EditDelete More ▾ Player PositionsPlayer Sport...
# 24  EditDelete More ▾ Player PositionsPlayer Sport...
# 25  EditDelete More ▾ Player PositionsPlayer Sport...
# 26  EditDelete More ▾ Player PositionsPlayer Sport...

# %%
df_pos = df_pos.drop(['Sport', 'Start Year','End Year','Default Name','Unnamed: 8'], axis=1)
df_pos.head()
# Out:
#               Platoon Position Group                     Name Abbreviation
# 0  Football (Offense)    Quarterback    Pro-Style Quarterback          PRO
# 1  Football (Offense)    Quarterback  Dual-Threat Quarterback         DUAL
# 2  Football (Offense)    Quarterback              Quarterback           QB
# 3  Football (Offense)   Running Back         All Purpose Back          APB
# 4  Football (Offense)   Running Back             Running Back           RB

# %%
df_pos.rename({'Platoon': 'type', 'Position Group': 'position_group', 'Name':'position_name',
           'Abbreviation': 'position'}, axis=1, inplace=True)

print(df_pos.shape)
df_pos.head()
# Out:
# (27, 4)
#                  type position_group            position_name position
# 0  Football (Offense)    Quarterback    Pro-Style Quarterback      PRO
# 1  Football (Offense)    Quarterback  Dual-Threat Quarterback     DUAL
# 2  Football (Offense)    Quarterback              Quarterback       QB
# 3  Football (Offense)   Running Back         All Purpose Back      APB
# 4  Football (Offense)   Running Back             Running Back       RB

# %%
df_pos.loc[df_pos.type.str.contains('Offense'), 'type'] = 'Offense'
df_pos.loc[df_pos.type.str.contains('Defense'), 'type'] = 'Defense'
df_pos.loc[df_pos.type.str.contains('Special'), 'type'] = 'Special Teams'

df_pos.head()
# Out:
#       type position_group            position_name position
# 0  Offense    Quarterback    Pro-Style Quarterback      PRO
# 1  Offense    Quarterback  Dual-Threat Quarterback     DUAL
# 2  Offense    Quarterback              Quarterback       QB
# 3  Offense   Running Back         All Purpose Back      APB
# 4  Offense   Running Back             Running Back       RB

# %%
df_pos = df_pos[['position', 'position_name', 'position_group', 'type']]
df_pos.head()
# Out:
#   position            position_name position_group     type
# 0      PRO    Pro-Style Quarterback    Quarterback  Offense
# 1     DUAL  Dual-Threat Quarterback    Quarterback  Offense
# 2       QB              Quarterback    Quarterback  Offense
# 3      APB         All Purpose Back   Running Back  Offense
# 4       RB             Running Back   Running Back  Offense

# %% [markdown]
# ### b.) Load CFB Team Info

# %%
df_team = pd.read_csv("cfb_team_info_all.csv", engine='python')
print(df_team.shape)
df_team.head()
# Out:
# (1693, 27)
#    ï»¿id             school     mascot abbreviation alt_name1 alt_name2  \
# 0   2000  Abilene Christian   Wildcats          ACU       NaN       ACU
# 1   2001        Adams State  Grizzlies         ADST       NaN      ADST
# 2   2003             Adrian   Bulldogs          ADR       NaN       ADR
# 3   2005          Air Force    Falcons          AFA       NaN       AFA
# 4   2006              Akron       Zips          AKR       NaN       AKR
#
#         alt_name3     conference  division    color  ... location.zip  \
# 0  Abil Christian            NaN       NaN  #4e2683  ...          NaN
# 1        Adams St            NaN       NaN  #000000  ...          NaN
# 2          Adrian            NaN       NaN  #000000  ...          NaN
# 3       Air Force  Mountain West  Mountain  #004a7b  ...      80840.0
# 4           Akron   Mid-American      East  #00285e  ...      44399.0
#
#   location.country_code location.timezone  location.latitude  \
# 0                   NaN               NaN                NaN
# 1                   NaN               NaN                NaN
# 2                   NaN               NaN                NaN
# 3                    US    America/Denver          38.996970
# 4                    US  America/New_York          41.072553
#
#   location.longitude location.elevation location.capacity  \
# 0                NaN                NaN               NaN
# 1                NaN                NaN               NaN
# 2                NaN                NaN               NaN
# 3        -104.843617        2024.875732           46692.0
# 4         -81.508341         321.287506           30000.0
#
#    location.year_constructed location.grass location.dome
# 0                        NaN            NaN           NaN
# 1                        NaN            NaN           NaN
# 2                        NaN            NaN           NaN
# 3                     1962.0          False         False
# 4                     2009.0          False         False
#
# [5 rows x 27 columns]

# %%
df_team.dtypes
# Out:
# ï»¿id                          int64
# school                        object
# mascot                        object
# abbreviation                  object
# alt_name1                     object
# alt_name2                     object
# alt_name3                     object
# conference                    object
# division                      object
# color                         object
# alt_color                     object
# logos[0]                      object
# logos[1]                      object
# location.venue_id            float64
# location.name                 object
# location.city                 object
# location.state                object
# location.zip                 float64
# location.country_code         object
# location.timezone             object
# location.latitude            float64
# location.longitude           float64
# location.elevation           float64
# location.capacity            float64
# location.year_constructed    float64
# location.grass                object
# location.dome                 object
# dtype: object

# %%
df_team2 = df_team[['school','conference','division','location.city','location.state','location.latitude','location.longitude']]
df_team2.head()
# Out:
#               school     conference  division     location.city  \
# 0  Abilene Christian            NaN       NaN               NaN
# 1        Adams State            NaN       NaN               NaN
# 2             Adrian            NaN       NaN               NaN
# 3          Air Force  Mountain West  Mountain  Colorado Springs
# 4              Akron   Mid-American      East             Akron
#
#   location.state  location.latitude  location.longitude
# 0            NaN                NaN                 NaN
# 1            NaN                NaN                 NaN
# 2            NaN                NaN                 NaN
# 3             CO          38.996970         -104.843617
# 4             OH          41.072553          -81.508341

# %%
# rename columns for more accurate/clean headers

df_team2.rename({'school': 'college_commit', 'location.city': 'college_city', 'location.state':'college_state',
           'location.latitude': 'college_lat', 'location.longitude': 'college_long'}, axis=1, inplace=True)

print(df_team2.shape)
df_team2.head()
# Out:
# (1693, 7)
# C:\Users\WiensJ01\Anaconda3\lib\site-packages\pandas\core\frame.py:4293: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#       college_commit     conference  division      college_city college_state  \
# 0  Abilene Christian            NaN       NaN               NaN           NaN
# 1        Adams State            NaN       NaN               NaN           NaN
# 2             Adrian            NaN       NaN               NaN           NaN
# 3          Air Force  Mountain West  Mountain  Colorado Springs            CO
# 4              Akron   Mid-American      East             Akron            OH
#
#    college_lat  college_long
# 0          NaN           NaN
# 1          NaN           NaN
# 2          NaN           NaN
# 3    38.996970   -104.843617
# 4    41.072553    -81.508341

# %%
df_sjs = df_team2[df_team2['college_commit'].str.contains("San J")]
df_sjs
# Out:
#       college_commit     conference division college_city college_state  \
# 527  San JosÃ© State  Mountain West     West     San Jose            CA
#
#      college_lat  college_long
# 527    37.319668   -121.868296

# %%
df_team2.loc[df_team2.college_commit.str.contains('San J', na=False), 'college_commit'] = 'San José State'

df_team2.loc[df_team2.college_commit.str.contains('San J', na=False)].head()
# Out:
# C:\Users\WiensJ01\Anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#      college_commit     conference division college_city college_state  \
# 527  San José State  Mountain West     West     San Jose            CA
#
#      college_lat  college_long
# 527    37.319668   -121.868296

# %%
# ensure all rows have values

df_team2.isnull().sum(axis = 0)
# Out:
# college_commit       0
# conference        1563
# division          1589
# college_city      1481
# college_state     1481
# college_lat       1481
# college_long      1481
# dtype: int64

# %%
# drop rows containing NaN values for selected columns

df_team2.dropna(subset=['college_city','college_state', 'college_lat','college_long'], inplace=True)

print(df_team2.shape)
df_team2.head()
# Out:
# (212, 7)
# <ipython-input-15-a5361e4a5b76>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_team2.dropna(subset=['college_city','college_state', 'college_lat','college_long'], inplace=True)
#   college_commit     conference  division      college_city college_state  \
# 3      Air Force  Mountain West  Mountain  Colorado Springs            CO
# 4          Akron   Mid-American      East             Akron            OH
# 5        Alabama            SEC      West        Tuscaloosa            AL
# 7  Alabama State            NaN       NaN        Montgomery            AL
# 8         Albany            NaN       NaN            Albany            NY
#
#    college_lat  college_long
# 3    38.996970   -104.843617
# 4    41.072553    -81.508341
# 5    33.208275    -87.550384
# 7    32.379490    -86.293002
# 8    42.680981    -73.827276

# %%
df_team2[['conference']] = df_team2[['conference']].fillna("FCS")
df_team2[['division']] = df_team2[['division']].fillna("fcs")
# Out:
# C:\Users\WiensJ01\Anaconda3\lib\site-packages\pandas\core\frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
# ensure all rows have values

df_team2.isnull().sum(axis = 0)
# Out:
# college_commit    0
# conference        0
# division          0
# college_city      0
# college_state     0
# college_lat       0
# college_long      0
# dtype: int64

# %% [markdown]
# ### Add in extra university location data for missing colleges

# %%
df_team_ex = pd.read_csv("cfb_team_info_extra.csv", engine='python')
print(df_team_ex.shape)
df_team_ex.head()
# Out:
# (60, 7)
#       college_commit conference division          city state        lat  \
# 0  Abilene Christian        FCS      FCS       Abilene    TX -99.709797
# 1        Alabama A&M        FCS      FCS        Normal    AL -86.568502
# 2              Brown        FCS      FCS    Providence    RI -71.403850
# 3             Butler        FCS      FCS  Indianapolis    IN -86.172167
# 4           Campbell        FCS      FCS   Buies Creek    NC -78.738238
#
#         long
# 0  32.468943
# 1  34.783368
# 2  41.826170
# 3  39.837400
# 4  35.409149

# %%
# rename columns for more accurate/clean headers

df_team_ex.rename({'school': 'college_commit', 'city': 'college_city', 'state':'college_state',
           'lat': 'college_lat', 'long': 'college_long'}, axis=1, inplace=True)

print(df_team_ex.shape)
df_team_ex.head()
# Out:
# (60, 7)
#       college_commit conference division  college_city college_state  \
# 0  Abilene Christian        FCS      FCS       Abilene            TX
# 1        Alabama A&M        FCS      FCS        Normal            AL
# 2              Brown        FCS      FCS    Providence            RI
# 3             Butler        FCS      FCS  Indianapolis            IN
# 4           Campbell        FCS      FCS   Buies Creek            NC
#
#    college_lat  college_long
# 0   -99.709797     32.468943
# 1   -86.568502     34.783368
# 2   -71.403850     41.826170
# 3   -86.172167     39.837400
# 4   -78.738238     35.409149

# %%
# ensure all rows have values

df_team_ex.isnull().sum(axis = 0)
# Out:
# college_commit    0
# conference        0
# division          0
# college_city      0
# college_state     0
# college_lat       0
# college_long      0
# dtype: int64

# %%
# concat extra college data onto existing dataframe

df_team1 = pd.concat([df_team2, df_team_ex], ignore_index=True)
df_team1.head(10)
# Out:
#       college_commit     conference  division      college_city college_state  \
# 0          Air Force  Mountain West  Mountain  Colorado Springs            CO
# 1              Akron   Mid-American      East             Akron            OH
# 2            Alabama            SEC      West        Tuscaloosa            AL
# 3      Alabama State            FCS       fcs        Montgomery            AL
# 4             Albany            FCS       fcs            Albany            NY
# 5       Alcorn State            FCS       fcs            Lorman            MS
# 6  Appalachian State       Sun Belt       fcs             Boone            NC
# 7            Arizona         Pac-12     South            Tucson            AZ
# 8      Arizona State         Pac-12     South             Tempe            AZ
# 9           Arkansas            SEC      West      Fayetteville            AR
#
#    college_lat  college_long
# 0    38.996970   -104.843617
# 1    41.072553    -81.508341
# 2    33.208275    -87.550384
# 3    32.379490    -86.293002
# 4    42.680981    -73.827276
# 5    31.873621    -91.134880
# 6    36.211427    -81.685428
# 7    32.228805   -110.948868
# 8    33.426447   -111.932500
# 9    36.068066    -94.178953

# %%
# ensure all rows have values

df_team_ex.isnull().sum(axis = 0)
# Out:
# college_commit    0
# conference        0
# division          0
# college_city      0
# college_state     0
# college_lat       0
# college_long      0
# dtype: int64

# %%
print(df_team1.shape)
df_team1.head()
# Out:
# (272, 7)
#   college_commit     conference  division      college_city college_state  \
# 0      Air Force  Mountain West  Mountain  Colorado Springs            CO
# 1          Akron   Mid-American      East             Akron            OH
# 2        Alabama            SEC      West        Tuscaloosa            AL
# 3  Alabama State            FCS       fcs        Montgomery            AL
# 4         Albany            FCS       fcs            Albany            NY
#
#    college_lat  college_long
# 0    38.996970   -104.843617
# 1    41.072553    -81.508341
# 2    33.208275    -87.550384
# 3    32.379490    -86.293002
# 4    42.680981    -73.827276

# %%
# check csv file for errors

df_team1.to_csv('cfb_team_check_V3.csv',encoding='utf-8-sig')

# %% [markdown]
# ### c. Load CFB Player Recruiting Data

# %%
df = pd.read_csv("2015-2021 CFB Recruiting Players data.csv", engine='python')
print(df.shape)
df.head()
# Out:
# (27179, 19)
#       id  athleteId recruitType  year  ranking              name  \
# 0  66928  3915192.0  HighSchool  2015      1.0  Trenton Thompson
# 1  31860        NaN  HighSchool  2015      1.0    Trent Thompson
# 2  31861 -1009710.0  HighSchool  2015      2.0       Martez Ivey
# 3  31862  3916922.0  HighSchool  2015      3.0      Byron Cowart
# 4  31863  3912545.0  HighSchool  2015      4.0     Iman Marshall
#
#             school committedTo position  height  weight  stars  rating  \
# 0         Westover     Georgia       DT    74.0   313.0      5  0.9992
# 1         Westover     Georgia       DT    74.5   313.0      5  0.9991
# 2           Apopka     Florida       OT    77.5   275.0      5  0.9990
# 3          Armwood      Auburn      SDE    76.0   250.0      5  0.9987
# 4  Long Beach Poly         USC       CB    73.0   190.0      5  0.9985
#
#          city stateProvince country  hometownInfo.latitude  \
# 0      Albany            GA     USA              31.578206
# 1      Albany            GA     USA              31.578206
# 2      Apopka            FL     USA              28.677968
# 3     Seffner            FL     USA              27.998541
# 4  Long Beach            CA     USA              33.769016
#
#    hometownInfo.longitude  hometownInfo.fipsCode
# 0              -84.155681                13095.0
# 1              -84.155681                13095.0
# 2              -81.511521                12095.0
# 3              -82.274884                12057.0
# 4             -118.191605                 6037.0

# %%
df.dtypes
# Out:
# id                          int64
# athleteId                 float64
# recruitType                object
# year                        int64
# ranking                   float64
# name                       object
# school                     object
# committedTo                object
# position                   object
# height                    float64
# weight                    float64
# stars                       int64
# rating                    float64
# city                       object
# stateProvince              object
# country                    object
# hometownInfo.latitude     float64
# hometownInfo.longitude    float64
# hometownInfo.fipsCode     float64
# dtype: object

# %%
df.isnull().sum(axis = 0)
# Out:
# id                            0
# athleteId                 11704
# recruitType                   0
# year                          0
# ranking                     360
# name                          0
# school                      275
# committedTo                5524
# position                     18
# height                       51
# weight                       55
# stars                         0
# rating                        0
# city                        298
# stateProvince               300
# country                     196
# hometownInfo.latitude       380
# hometownInfo.longitude      380
# hometownInfo.fipsCode       391
# dtype: int64

# %%
df.nunique(axis=0)
# Out:
# id                        27179
# athleteId                 15182
# recruitType                   1
# year                          7
# ranking                    4257
# name                      25912
# school                     5291
# committedTo                 271
# position                     22
# height                       57
# weight                      244
# stars                         5
# rating                     2186
# city                       3034
# stateProvince                60
# country                      17
# hometownInfo.latitude      3611
# hometownInfo.longitude     3611
# hometownInfo.fipsCode      1571
# dtype: int64

# %%
df = df.drop(['athleteId', 'recruitType','country'], axis=1)

# %%
df['year'].value_counts()
# Out:
# 2017    4359
# 2020    4307
# 2019    4165
# 2016    4053
# 2018    3950
# 2015    3608
# 2021    2737
# Name: year, dtype: int64

# %%
df1 = df.drop_duplicates(
    subset=['year','ranking'], 
    keep="first").reset_index(drop=True)
print(df1.shape)
df1.head()
# Out:
# (26403, 16)
#       id  year  ranking              name              school    committedTo  \
# 0  66928  2015      1.0  Trenton Thompson            Westover        Georgia
# 1  31861  2015      2.0       Martez Ivey              Apopka        Florida
# 2  31862  2015      3.0      Byron Cowart             Armwood         Auburn
# 3  31863  2015      4.0     Iman Marshall     Long Beach Poly            USC
# 4  31864  2015      5.0      Derwin James  Haines City Senior  Florida State
#
#   position  height  weight  stars  rating        city stateProvince  \
# 0       DT    74.0   313.0      5  0.9992      Albany            GA
# 1       OT    77.5   275.0      5  0.9990      Apopka            FL
# 2      SDE    76.0   250.0      5  0.9987     Seffner            FL
# 3       CB    73.0   190.0      5  0.9985  Long Beach            CA
# 4        S    74.0   201.0      5  0.9981  Auburndale            FL
#
#    hometownInfo.latitude  hometownInfo.longitude  hometownInfo.fipsCode
# 0              31.578206              -84.155681                13095.0
# 1              28.677968              -81.511521                12095.0
# 2              27.998541              -82.274884                12057.0
# 3              33.769016             -118.191605                 6037.0
# 4              28.107088              -81.803580                12105.0

# %%
df1.isnull().sum(axis = 0)
# Out:
# id                           0
# year                         0
# ranking                      3
# name                         0
# school                      30
# committedTo               5361
# position                    10
# height                      46
# weight                      50
# stars                        0
# rating                       0
# city                       125
# stateProvince              127
# hometownInfo.latitude      204
# hometownInfo.longitude     204
# hometownInfo.fipsCode      213
# dtype: int64

# %%
df1['year'].value_counts()
# Out:
# 2017    4252
# 2019    4090
# 2016    3978
# 2020    3934
# 2018    3887
# 2015    3547
# 2021    2715
# Name: year, dtype: int64

# %%
df1[['committedTo']] = df1[['committedTo']].fillna("Uncommitted")

# %%
# pd.set_option('display.max_rows',500)

df1_group = df1.groupby(['committedTo','year']).size().unstack(fill_value=0)
df1_group.head()
# Out:
# year               2015  2016  2017  2018  2019  2020  2021
# committedTo
# Abilene Christian     2     8     3     0     0     0     0
# Air Force            22    40    59    26    51    33    47
# Akron                14     7    20    14    22    17    16
# Alabama              24    22    27    21    27    24    26
# Alabama A&M           0     1     1     1     1     0     1

# %%
# check uncommitted recruit totals
df1_group.query('committedTo== "Uncommitted"')
# Out:
# year         2015  2016  2017  2018  2019  2020  2021
# committedTo
# Uncommitted   549   763   958   829  1042   996   224

# %%
df1.isnull().sum(axis = 0)
# Out:
# id                          0
# year                        0
# ranking                     3
# name                        0
# school                     30
# committedTo                 0
# position                   10
# height                     46
# weight                     50
# stars                       0
# rating                      0
# city                      125
# stateProvince             127
# hometownInfo.latitude     204
# hometownInfo.longitude    204
# hometownInfo.fipsCode     213
# dtype: int64

# %%
# drop rows containing NaN values for selected columns

df1.dropna(subset=['school','ranking', 'position','city', 'stateProvince',
                   'hometownInfo.latitude','hometownInfo.longitude','hometownInfo.fipsCode'], inplace=True)

print(df1.shape)
df1.head()
# Out:
# (26159, 16)
#       id  year  ranking              name              school    committedTo  \
# 0  66928  2015      1.0  Trenton Thompson            Westover        Georgia
# 1  31861  2015      2.0       Martez Ivey              Apopka        Florida
# 2  31862  2015      3.0      Byron Cowart             Armwood         Auburn
# 3  31863  2015      4.0     Iman Marshall     Long Beach Poly            USC
# 4  31864  2015      5.0      Derwin James  Haines City Senior  Florida State
#
#   position  height  weight  stars  rating        city stateProvince  \
# 0       DT    74.0   313.0      5  0.9992      Albany            GA
# 1       OT    77.5   275.0      5  0.9990      Apopka            FL
# 2      SDE    76.0   250.0      5  0.9987     Seffner            FL
# 3       CB    73.0   190.0      5  0.9985  Long Beach            CA
# 4        S    74.0   201.0      5  0.9981  Auburndale            FL
#
#    hometownInfo.latitude  hometownInfo.longitude  hometownInfo.fipsCode
# 0              31.578206              -84.155681                13095.0
# 1              28.677968              -81.511521                12095.0
# 2              27.998541              -82.274884                12057.0
# 3              33.769016             -118.191605                 6037.0
# 4              28.107088              -81.803580                12105.0

# %%
df_sjs1 = df1[df1['committedTo'].str.contains("San")]
df_sjs1
# Out:
#           id  year  ranking             name               school  \
# 217    32075  2015    218.0    Desean Holmes       Bishop Alemany
# 244    32124  2015    245.0    Kyahva Tezino             Salesian
# 327    32202  2015    329.0       Kanya Bell      Long Beach Poly
# 352    32205  2015    354.0      Taeon Mason            John Muir
# 680    32537  2015    682.0     Jeremy Kelly             Salesian
# ...      ...   ...      ...              ...                  ...
# 26040  73778  2021   2354.0      D.J. Bryant          San Leandro
# 26146  73870  2021   2460.0    Robert Rigsby               Judson
# 26211  73925  2021   2525.0  Kekona Tinajero             Rio Mesa
# 26258  73967  2021   2572.0     Ryan Stewart     Lincoln-Way East
# 26295  75350  2021   2609.0   Collyn Hopkins  Bradley-Bourbonnais
#
#            committedTo position  height  weight  stars  rating         city  \
# 217    San Diego State       WR    70.5   170.0      4  0.9127     Pasadena
# 244    San Diego State      OLB    72.0   207.0      4  0.9080  Los Angeles
# 327    San JosÃ© State       WR    72.0   160.0      4  0.8914  Diamond Bar
# 352    San JosÃ© State       CB    72.0   170.0      3  0.8887     Pasadena
# 680    San JosÃ© State       WR    73.0   169.0      3  0.8584  Los Angeles
# ...                ...      ...     ...     ...    ...     ...          ...
# 26040  San Diego State     DUAL    72.0   170.0      3  0.8024  San Leandro
# 26146   UT San Antonio       OC    75.0   310.0      2  0.7963     Converse
# 26211        San Diego      ATH    72.0   175.0      2  0.7932       Oxnard
# 26258  San JosÃ© State       OT    77.0   240.0      2  0.7889    Frankfort
# 26295  San Diego State        K    74.0   210.0      2  0.7841      Bradley
#
#       stateProvince  hometownInfo.latitude  hometownInfo.longitude  \
# 217              CA              34.147645             -118.144478
# 244              CA              34.053691             -118.242767
# 327              CA              34.028623             -117.810337
# 352              CA              34.147645             -118.144478
# 680              CA              34.053691             -118.242767
# ...             ...                    ...                     ...
# 26040            CA              37.724930             -122.156077
# 26146            TX              29.518008              -98.316124
# 26211            CA              34.197631             -119.180382
# 26258            IL              41.495866              -87.848661
# 26295            IL              41.142191              -87.861322
#
#        hometownInfo.fipsCode
# 217                   6037.0
# 244                   6037.0
# 327                   6037.0
# 352                   6037.0
# 680                   6037.0
# ...                      ...
# 26040                 6001.0
# 26146                48029.0
# 26211                 6111.0
# 26258                17197.0
# 26295                17091.0
#
# [396 rows x 16 columns]

# %%
df1.loc[df1.committedTo.str.contains('San J', na=False), 'committedTo'] = 'San José State'

df1.loc[df1.committedTo.str.contains('San J', na=False)].head()
# Out:
#         id  year  ranking                 name           school  \
# 327  32202  2015    329.0           Kanya Bell  Long Beach Poly
# 352  32205  2015    354.0          Taeon Mason        John Muir
# 680  32537  2015    682.0         Jeremy Kelly         Salesian
# 886  32742  2015    888.0       Malik Roberson   Junipero Serra
# 910  32767  2015    912.0  Dominic Fredrickson          Freedom
#
#         committedTo position  height  weight  stars  rating         city  \
# 327  San José State       WR    72.0   160.0      4  0.8914  Diamond Bar
# 352  San José State       CB    72.0   170.0      3  0.8887     Pasadena
# 680  San José State       WR    73.0   169.0      3  0.8584  Los Angeles
# 886  San José State      APB    67.0   170.0      3  0.8497      Gardena
# 910  San José State       OG    75.0   295.0      3  0.8487       Oakley
#
#     stateProvince  hometownInfo.latitude  hometownInfo.longitude  \
# 327            CA              34.028623             -117.810337
# 352            CA              34.147645             -118.144478
# 680            CA              34.053691             -118.242767
# 886            CA              33.896359             -118.305304
# 910            CA              37.997422             -121.712454
#
#      hometownInfo.fipsCode
# 327                 6037.0
# 352                 6037.0
# 680                 6037.0
# 886                 6037.0
# 910                 6013.0

# %%
df1.isnull().sum(axis = 0)
# Out:
# id                         0
# year                       0
# ranking                    0
# name                       0
# school                     0
# committedTo                0
# position                   0
# height                    43
# weight                    46
# stars                      0
# rating                     0
# city                       0
# stateProvince              0
# hometownInfo.latitude      0
# hometownInfo.longitude     0
# hometownInfo.fipsCode      0
# dtype: int64

# %%
# check recruits who do not have height listed
df1[df1['height'].isna()].head()
# Out:
#          id  year  ranking              name                school  \
# 1328  66964  2015   1331.0  Ronique Robinson  Booker T. Washington
# 2962  67114  2015   2969.0         Kiki Hill                Goliad
# 5059  36638  2016   1513.0   Kailen Guillory             Ben Davis
# 5535  37099  2016   1989.0   Taeshon Trotter        Cass Technical
# 5540  37104  2016   1994.0       Kee Whetzel           Countryside
#
#            committedTo position  height  weight  stars  rating          city  \
# 1328       Uncommitted      WDE     NaN     NaN      3  0.8333         Miami
# 2962       Uncommitted       WR     NaN     NaN      2  0.7667        Goliad
# 5059  Western Michigan      WDE     NaN     NaN      3  0.8240  Indianapolis
# 5535              Ohio       OT     NaN     NaN      3  0.8039       Detroit
# 5540      Oregon State       WR     NaN   186.0      3  0.8036    Clearwater
#
#      stateProvince  hometownInfo.latitude  hometownInfo.longitude  \
# 1328            FL              25.774266              -80.193659
# 2962            TX              28.668656              -97.390912
# 5059            IN              39.768333              -86.158350
# 5535            MI              42.331551              -83.046640
# 5540            FL              27.965853              -82.800103
#
#       hometownInfo.fipsCode
# 1328                12086.0
# 2962                48175.0
# 5059                18097.0
# 5535                26163.0
# 5540                12103.0

# %%
# impute mean height by position to missing height values
df1.height = df1.groupby('position')['height'].apply(lambda x: x.fillna(x.mean()))
df1.height = df1.height.fillna(df1.height.mean())

# %%
# impute mean weight by position to missing weight values
df1.weight = df1.groupby('position')['weight'].apply(lambda x: x.fillna(x.mean()))
df1.weight = df1.weight.fillna(df1.weight.mean())

# %%
# check for one of the players without height/weight listed 

df1[df1['name'] == "Kiki Hill"]
# Out:
#          id  year  ranking       name  school  committedTo position  \
# 2962  67114  2015   2969.0  Kiki Hill  Goliad  Uncommitted       WR
#
#          height      weight  stars  rating    city stateProvince  \
# 2962  72.887123  182.179795      2  0.7667  Goliad            TX
#
#       hometownInfo.latitude  hometownInfo.longitude  hometownInfo.fipsCode
# 2962              28.668656              -97.390912                48175.0

# %%
# ensure all rows have values

df1.isnull().sum(axis = 0)
# Out:
# id                        0
# year                      0
# ranking                   0
# name                      0
# school                    0
# committedTo               0
# position                  0
# height                    0
# weight                    0
# stars                     0
# rating                    0
# city                      0
# stateProvince             0
# hometownInfo.latitude     0
# hometownInfo.longitude    0
# hometownInfo.fipsCode     0
# dtype: int64

# %% [markdown]
# ## 2. Add County names based on FIPS code

# %%
# load new dataframe with fips codes and county names

url ='https://www2.census.gov/geo/docs/reference/codes/files/national_county.txt'
df_5 = pd.read_csv(url, header=None, sep=",",names=['state','fips1','fips2','county','E'],dtype=str)
df_5.head()
# Out:
#   state fips1 fips2          county   E
# 0    AL    01   001  Autauga County  H1
# 1    AL    01   003  Baldwin County  H1
# 2    AL    01   005  Barbour County  H1
# 3    AL    01   007     Bibb County  H1
# 4    AL    01   009   Blount County  H1

# %%
df_5['hometownInfo.fipsCode'] = df_5['fips1'] + df_5['fips2']
df_5.head()
# Out:
#   state fips1 fips2          county   E hometownInfo.fipsCode
# 0    AL    01   001  Autauga County  H1                 01001
# 1    AL    01   003  Baldwin County  H1                 01003
# 2    AL    01   005  Barbour County  H1                 01005
# 3    AL    01   007     Bibb County  H1                 01007
# 4    AL    01   009   Blount County  H1                 01009

# %%
df6 = df_5[['hometownInfo.fipsCode','county']].copy()
df6['hometownInfo.fipsCode'] = pd.to_numeric(df6['hometownInfo.fipsCode'])
df6.head()
# Out:
#    hometownInfo.fipsCode          county
# 0                   1001  Autauga County
# 1                   1003  Baldwin County
# 2                   1005  Barbour County
# 3                   1007     Bibb County
# 4                   1009   Blount County

# %%
# merge county names onto existing dataframe

df2 = df1.merge(df6, on='hometownInfo.fipsCode', how='left')
df2.head(10)
# Out:
#       id  year  ranking              name                     school  \
# 0  66928  2015      1.0  Trenton Thompson                   Westover
# 1  31861  2015      2.0       Martez Ivey                     Apopka
# 2  31862  2015      3.0      Byron Cowart                    Armwood
# 3  31863  2015      4.0     Iman Marshall            Long Beach Poly
# 4  31864  2015      5.0      Derwin James         Haines City Senior
# 5  31865  2015      6.0   Kahlil McKenzie             Clayton Valley
# 6  31866  2015      7.0    CeCe Jefferson        Baker County Senior
# 7  31867  2015      8.0        Josh Sweat                Oscar Smith
# 8  31868  2015      9.0  Kevin Toliver II  Trinity Christian Academy
# 9  31869  2015     10.0   Malik Jefferson                     Poteet
#
#      committedTo position  height  weight  stars  rating             city  \
# 0        Georgia       DT    74.0   313.0      5  0.9992           Albany
# 1        Florida       OT    77.5   275.0      5  0.9990           Apopka
# 2         Auburn      SDE    76.0   250.0      5  0.9987          Seffner
# 3            USC       CB    73.0   190.0      5  0.9985       Long Beach
# 4  Florida State        S    74.0   201.0      5  0.9981       Auburndale
# 5      Tennessee       DT    75.0   339.0      5  0.9968          Concord
# 6        Florida      SDE    74.0   275.0      5  0.9951  Glen Saint Mary
# 7  Florida State      WDE    77.0   240.0      5  0.9948       Chesapeake
# 8            LSU       CB    74.0   185.0      5  0.9948     Jacksonville
# 9          Texas      OLB    74.5   215.0      5  0.9929         Mesquite
#
#   stateProvince  hometownInfo.latitude  hometownInfo.longitude  \
# 0            GA              31.578206              -84.155681
# 1            FL              28.677968              -81.511521
# 2            FL              27.998541              -82.274884
# 3            CA              33.769016             -118.191605
# 4            FL              28.107088              -81.803580
# 5            CA              37.976852             -122.033562
# 6            FL              30.275791              -82.160669
# 7            VA              36.718371              -76.246680
# 8            FL              30.332184              -81.655651
# 9            TX              32.766610              -96.599472
#
#    hometownInfo.fipsCode               county
# 0                13095.0     Dougherty County
# 1                12095.0        Orange County
# 2                12057.0  Hillsborough County
# 3                 6037.0   Los Angeles County
# 4                12105.0          Polk County
# 5                 6013.0  Contra Costa County
# 6                12003.0         Baker County
# 7                51550.0      Chesapeake city
# 8                12031.0         Duval County
# 9                48113.0        Dallas County

# %%
df2.isnull().sum(axis = 0)
# Out:
# id                        0
# year                      0
# ranking                   0
# name                      0
# school                    0
# committedTo               0
# position                  0
# height                    0
# weight                    0
# stars                     0
# rating                    0
# city                      0
# stateProvince             0
# hometownInfo.latitude     0
# hometownInfo.longitude    0
# hometownInfo.fipsCode     0
# county                    0
# dtype: int64

# %%
# rename columns for more accurate/clean headers

df2.rename({'school': 'high_school', 'committedTo': 'college_commit', 'stateProvince': 'state',
           'hometownInfo.latitude': 'hometown_lat', 'hometownInfo.longitude': 'hometown_long', 
            'hometownInfo.fipsCode': 'hometown_fips'}, axis=1, inplace=True)

print(df2.shape)
df2.head()
# Out:
# (26159, 17)
#       id  year  ranking              name         high_school college_commit  \
# 0  66928  2015      1.0  Trenton Thompson            Westover        Georgia
# 1  31861  2015      2.0       Martez Ivey              Apopka        Florida
# 2  31862  2015      3.0      Byron Cowart             Armwood         Auburn
# 3  31863  2015      4.0     Iman Marshall     Long Beach Poly            USC
# 4  31864  2015      5.0      Derwin James  Haines City Senior  Florida State
#
#   position  height  weight  stars  rating        city state  hometown_lat  \
# 0       DT    74.0   313.0      5  0.9992      Albany    GA     31.578206
# 1       OT    77.5   275.0      5  0.9990      Apopka    FL     28.677968
# 2      SDE    76.0   250.0      5  0.9987     Seffner    FL     27.998541
# 3       CB    73.0   190.0      5  0.9985  Long Beach    CA     33.769016
# 4        S    74.0   201.0      5  0.9981  Auburndale    FL     28.107088
#
#    hometown_long  hometown_fips               county
# 0     -84.155681        13095.0     Dougherty County
# 1     -81.511521        12095.0        Orange County
# 2     -82.274884        12057.0  Hillsborough County
# 3    -118.191605         6037.0   Los Angeles County
# 4     -81.803580        12105.0          Polk County

# %%
# check data types 

df2.dtypes
# Out:
# id                  int64
# year                int64
# ranking           float64
# name               object
# high_school        object
# college_commit     object
# position           object
# height            float64
# weight            float64
# stars               int64
# rating            float64
# city               object
# state              object
# hometown_lat      float64
# hometown_long     float64
# hometown_fips     float64
# county             object
# dtype: object

# %%
# merge position data onto existing dateframe

df3 = df2.merge(df_pos, on='position', how='left')
print(df3.shape)
df3.head(10)
# Out:
# (26159, 20)
#       id  year  ranking              name                high_school  \
# 0  66928  2015      1.0  Trenton Thompson                   Westover
# 1  31861  2015      2.0       Martez Ivey                     Apopka
# 2  31862  2015      3.0      Byron Cowart                    Armwood
# 3  31863  2015      4.0     Iman Marshall            Long Beach Poly
# 4  31864  2015      5.0      Derwin James         Haines City Senior
# 5  31865  2015      6.0   Kahlil McKenzie             Clayton Valley
# 6  31866  2015      7.0    CeCe Jefferson        Baker County Senior
# 7  31867  2015      8.0        Josh Sweat                Oscar Smith
# 8  31868  2015      9.0  Kevin Toliver II  Trinity Christian Academy
# 9  31869  2015     10.0   Malik Jefferson                     Poteet
#
#   college_commit position  height  weight  stars  rating             city  \
# 0        Georgia       DT    74.0   313.0      5  0.9992           Albany
# 1        Florida       OT    77.5   275.0      5  0.9990           Apopka
# 2         Auburn      SDE    76.0   250.0      5  0.9987          Seffner
# 3            USC       CB    73.0   190.0      5  0.9985       Long Beach
# 4  Florida State        S    74.0   201.0      5  0.9981       Auburndale
# 5      Tennessee       DT    75.0   339.0      5  0.9968          Concord
# 6        Florida      SDE    74.0   275.0      5  0.9951  Glen Saint Mary
# 7  Florida State      WDE    77.0   240.0      5  0.9948       Chesapeake
# 8            LSU       CB    74.0   185.0      5  0.9948     Jacksonville
# 9          Texas      OLB    74.5   215.0      5  0.9929         Mesquite
#
#   state  hometown_lat  hometown_long  hometown_fips               county  \
# 0    GA     31.578206     -84.155681        13095.0     Dougherty County
# 1    FL     28.677968     -81.511521        12095.0        Orange County
# 2    FL     27.998541     -82.274884        12057.0  Hillsborough County
# 3    CA     33.769016    -118.191605         6037.0   Los Angeles County
# 4    FL     28.107088     -81.803580        12105.0          Polk County
# 5    CA     37.976852    -122.033562         6013.0  Contra Costa County
# 6    FL     30.275791     -82.160669        12003.0         Baker County
# 7    VA     36.718371     -76.246680        51550.0      Chesapeake city
# 8    FL     30.332184     -81.655651        12031.0         Duval County
# 9    TX     32.766610     -96.599472        48113.0        Dallas County
#
#                position_name  position_group     type
# 0           Defensive Tackle  Defensive Line  Defense
# 1           Offensive Tackle  Offensive Line  Offense
# 2  Strong-Side Defensive End  Defensive Line  Defense
# 3                 Cornerback  Defensive Back  Defense
# 4                     Safety  Defensive Back  Defense
# 5           Defensive Tackle  Defensive Line  Defense
# 6  Strong-Side Defensive End  Defensive Line  Defense
# 7    Weak-Side Defensive End  Defensive Line  Defense
# 8                 Cornerback  Defensive Back  Defense
# 9         Outside Linebacker      Linebacker  Defense

# %%
df4 = df3.merge(df_team1, on='college_commit', how='left')
print(df4.shape)
df4.head(10)
# Out:
# (26159, 26)
#       id  year  ranking              name                high_school  \
# 0  66928  2015      1.0  Trenton Thompson                   Westover
# 1  31861  2015      2.0       Martez Ivey                     Apopka
# 2  31862  2015      3.0      Byron Cowart                    Armwood
# 3  31863  2015      4.0     Iman Marshall            Long Beach Poly
# 4  31864  2015      5.0      Derwin James         Haines City Senior
# 5  31865  2015      6.0   Kahlil McKenzie             Clayton Valley
# 6  31866  2015      7.0    CeCe Jefferson        Baker County Senior
# 7  31867  2015      8.0        Josh Sweat                Oscar Smith
# 8  31868  2015      9.0  Kevin Toliver II  Trinity Christian Academy
# 9  31869  2015     10.0   Malik Jefferson                     Poteet
#
#   college_commit position  height  weight  stars  ...               county  \
# 0        Georgia       DT    74.0   313.0      5  ...     Dougherty County
# 1        Florida       OT    77.5   275.0      5  ...        Orange County
# 2         Auburn      SDE    76.0   250.0      5  ...  Hillsborough County
# 3            USC       CB    73.0   190.0      5  ...   Los Angeles County
# 4  Florida State        S    74.0   201.0      5  ...          Polk County
# 5      Tennessee       DT    75.0   339.0      5  ...  Contra Costa County
# 6        Florida      SDE    74.0   275.0      5  ...         Baker County
# 7  Florida State      WDE    77.0   240.0      5  ...      Chesapeake city
# 8            LSU       CB    74.0   185.0      5  ...         Duval County
# 9          Texas      OLB    74.5   215.0      5  ...        Dallas County
#
#                position_name  position_group     type  conference  division  \
# 0           Defensive Tackle  Defensive Line  Defense         SEC      East
# 1           Offensive Tackle  Offensive Line  Offense         SEC      East
# 2  Strong-Side Defensive End  Defensive Line  Defense         SEC      West
# 3                 Cornerback  Defensive Back  Defense      Pac-12     South
# 4                     Safety  Defensive Back  Defense         ACC  Atlantic
# 5           Defensive Tackle  Defensive Line  Defense         SEC      East
# 6  Strong-Side Defensive End  Defensive Line  Defense         SEC      East
# 7    Weak-Side Defensive End  Defensive Line  Defense         ACC  Atlantic
# 8                 Cornerback  Defensive Back  Defense         SEC      West
# 9         Outside Linebacker      Linebacker  Defense      Big 12       fcs
#
#   college_city college_state college_lat college_long
# 0       Athens            GA   33.949820   -83.373381
# 1  Gainesville            FL   29.649936   -82.348579
# 2       Auburn            AL   32.602553   -85.489748
# 3  Los Angeles            CA   34.014167  -118.287778
# 4  Tallahassee            FL   30.438169   -84.304403
# 5    Knoxville            TN   35.955013   -83.925013
# 6  Gainesville            FL   29.649936   -82.348579
# 7  Tallahassee            FL   30.438169   -84.304403
# 8  Baton Rouge            LA   30.412035   -91.183816
# 9       Austin            TX   30.283681   -97.732534
#
# [10 rows x 26 columns]

# %%
df4.isnull().sum(axis = 0)
# Out:
# id                   0
# year                 0
# ranking              0
# name                 0
# high_school          0
# college_commit       0
# position             0
# height               0
# weight               0
# stars                0
# rating               0
# city                 0
# state                0
# hometown_lat         0
# hometown_long        0
# hometown_fips        0
# county               0
# position_name        0
# position_group       0
# type                 0
# conference        5326
# division          5326
# college_city      5326
# college_state     5326
# college_lat       5326
# college_long      5326
# dtype: int64

# %%
# Fill 'uncommitted' as conference value for uncommitted recruits

df4[['conference']] = df4[['conference']].fillna("None")

# %%
# Fill in hometown location data for uncommitted recruits

df4.loc[df4["college_city"].isnull(),'college_city'] = df4["city"]
df4.loc[df4["college_state"].isnull(),'college_state'] = df4["state"]
df4.loc[df4["college_lat"].isnull(),'college_lat'] = df4["hometown_lat"]
df4.loc[df4["college_long"].isnull(),'college_long'] = df4["hometown_long"]

# %%
print(df4.shape)
df4.head(10)
# Out:
# (26159, 26)
#       id  year  ranking              name                high_school  \
# 0  66928  2015      1.0  Trenton Thompson                   Westover
# 1  31861  2015      2.0       Martez Ivey                     Apopka
# 2  31862  2015      3.0      Byron Cowart                    Armwood
# 3  31863  2015      4.0     Iman Marshall            Long Beach Poly
# 4  31864  2015      5.0      Derwin James         Haines City Senior
# 5  31865  2015      6.0   Kahlil McKenzie             Clayton Valley
# 6  31866  2015      7.0    CeCe Jefferson        Baker County Senior
# 7  31867  2015      8.0        Josh Sweat                Oscar Smith
# 8  31868  2015      9.0  Kevin Toliver II  Trinity Christian Academy
# 9  31869  2015     10.0   Malik Jefferson                     Poteet
#
#   college_commit position  height  weight  stars  ...               county  \
# 0        Georgia       DT    74.0   313.0      5  ...     Dougherty County
# 1        Florida       OT    77.5   275.0      5  ...        Orange County
# 2         Auburn      SDE    76.0   250.0      5  ...  Hillsborough County
# 3            USC       CB    73.0   190.0      5  ...   Los Angeles County
# 4  Florida State        S    74.0   201.0      5  ...          Polk County
# 5      Tennessee       DT    75.0   339.0      5  ...  Contra Costa County
# 6        Florida      SDE    74.0   275.0      5  ...         Baker County
# 7  Florida State      WDE    77.0   240.0      5  ...      Chesapeake city
# 8            LSU       CB    74.0   185.0      5  ...         Duval County
# 9          Texas      OLB    74.5   215.0      5  ...        Dallas County
#
#                position_name  position_group     type  conference  division  \
# 0           Defensive Tackle  Defensive Line  Defense         SEC      East
# 1           Offensive Tackle  Offensive Line  Offense         SEC      East
# 2  Strong-Side Defensive End  Defensive Line  Defense         SEC      West
# 3                 Cornerback  Defensive Back  Defense      Pac-12     South
# 4                     Safety  Defensive Back  Defense         ACC  Atlantic
# 5           Defensive Tackle  Defensive Line  Defense         SEC      East
# 6  Strong-Side Defensive End  Defensive Line  Defense         SEC      East
# 7    Weak-Side Defensive End  Defensive Line  Defense         ACC  Atlantic
# 8                 Cornerback  Defensive Back  Defense         SEC      West
# 9         Outside Linebacker      Linebacker  Defense      Big 12       fcs
#
#   college_city college_state college_lat college_long
# 0       Athens            GA   33.949820   -83.373381
# 1  Gainesville            FL   29.649936   -82.348579
# 2       Auburn            AL   32.602553   -85.489748
# 3  Los Angeles            CA   34.014167  -118.287778
# 4  Tallahassee            FL   30.438169   -84.304403
# 5    Knoxville            TN   35.955013   -83.925013
# 6  Gainesville            FL   29.649936   -82.348579
# 7  Tallahassee            FL   30.438169   -84.304403
# 8  Baton Rouge            LA   30.412035   -91.183816
# 9       Austin            TX   30.283681   -97.732534
#
# [10 rows x 26 columns]

# %%
df4.isnull().sum(axis = 0)
# Out:
# id                   0
# year                 0
# ranking              0
# name                 0
# high_school          0
# college_commit       0
# position             0
# height               0
# weight               0
# stars                0
# rating               0
# city                 0
# state                0
# hometown_lat         0
# hometown_long        0
# hometown_fips        0
# county               0
# position_name        0
# position_group       0
# type                 0
# conference           0
# division          5326
# college_city         0
# college_state        0
# college_lat          0
# college_long         0
# dtype: int64

# %% [markdown]
# ## 3. Export to CSV to check

# %%
# check csv file for errors

df4.to_csv('2015_2021_Recruits_V6.csv',encoding='utf-8-sig')

# %% [markdown]
# ## 4. Node Prep: Final Dataframes after Cleaning

# %%
# Players Node

player_df = df4[['id','year','name','height','weight']]
print(player_df.shape)
player_df.head()
# Out:
# (26159, 5)
#       id  year              name  height  weight
# 0  66928  2015  Trenton Thompson    74.0   313.0
# 1  31861  2015       Martez Ivey    77.5   275.0
# 2  31862  2015      Byron Cowart    76.0   250.0
# 3  31863  2015     Iman Marshall    73.0   190.0
# 4  31864  2015      Derwin James    74.0   201.0

# %%
# Ratings Node

rating_df = df4[['id','year','ranking','stars','rating']]
print(rating_df.shape)
rating_df.head()
# Out:
# (26159, 5)
#       id  year  ranking  stars  rating
# 0  66928  2015      1.0      5  0.9992
# 1  31861  2015      2.0      5  0.9990
# 2  31862  2015      3.0      5  0.9987
# 3  31863  2015      4.0      5  0.9985
# 4  31864  2015      5.0      5  0.9981

# %%
# Hometown Node

hometown_df = df4[['id','city','hometown_fips','county','state','hometown_lat','hometown_long']]
print(hometown_df.shape)
hometown_df.head()
# Out:
# (26159, 7)
#       id        city  hometown_fips               county state  hometown_lat  \
# 0  66928      Albany        13095.0     Dougherty County    GA     31.578206
# 1  31861      Apopka        12095.0        Orange County    FL     28.677968
# 2  31862     Seffner        12057.0  Hillsborough County    FL     27.998541
# 3  31863  Long Beach         6037.0   Los Angeles County    CA     33.769016
# 4  31864  Auburndale        12105.0          Polk County    FL     28.107088
#
#    hometown_long
# 0     -84.155681
# 1     -81.511521
# 2     -82.274884
# 3    -118.191605
# 4     -81.803580

# %%
# Position Node

position_df = df4[['id','position','position_name','position_group','type']]
print(position_df.shape)
position_df.head()
# Out:
# (26159, 5)
#       id position              position_name  position_group     type
# 0  66928       DT           Defensive Tackle  Defensive Line  Defense
# 1  31861       OT           Offensive Tackle  Offensive Line  Offense
# 2  31862      SDE  Strong-Side Defensive End  Defensive Line  Defense
# 3  31863       CB                 Cornerback  Defensive Back  Defense
# 4  31864        S                     Safety  Defensive Back  Defense

# %%
# School Node

school_df = df4[['id','high_school']]
print(school_df.shape)
school_df.head()
# Out:
# (26159, 2)
#       id         high_school
# 0  66928            Westover
# 1  31861              Apopka
# 2  31862             Armwood
# 3  31863     Long Beach Poly
# 4  31864  Haines City Senior

# %%
# College Node

college_df = df4[['id','college_commit','conference','college_state','college_lat','college_long']]
print(college_df.shape)
college_df.head()
# Out:
# (26159, 6)
#       id college_commit conference college_state  college_lat  college_long
# 0  66928        Georgia        SEC            GA    33.949820    -83.373381
# 1  31861        Florida        SEC            FL    29.649936    -82.348579
# 2  31862         Auburn        SEC            AL    32.602553    -85.489748
# 3  31863            USC     Pac-12            CA    34.014167   -118.287778
# 4  31864  Florida State        ACC            FL    30.438169    -84.304403

# %%
# export dataframes 

player_df.to_csv('data/player.csv', index=False)
rating_df.to_csv('data/rating.csv', index=False)
hometown_df.to_csv('data/hometown.csv', index=False)
position_df.to_csv('data/positionV2.csv', index=False)
school_df.to_csv('data/school.csv', index=False)
college_df.to_csv('data/collegeV2.csv', index=False)

# %% [markdown]
# ## 5. Cypher Import Script

# %%
CREATE CONSTRAINT ON (n:Player) ASSERT n.id is UNIQUE;
CREATE CONSTRAINT ON (n:Rating) ASSERT n.id is UNIQUE; 
CREATE CONSTRAINT ON (n:Hometown) ASSERT n.id is UNIQUE; 
CREATE CONSTRAINT ON (n:Position) ASSERT n.position is UNIQUE; 
CREATE CONSTRAINT ON (n:School) ASSERT n.high_school is UNIQUE; 
CREATE CONSTRAINT ON (n:College) ASSERT n.college_commit is UNIQUE;

LOAD CSV WITH HEADERS FROM 'file:///player.csv' AS row
CREATE(:Player
{
    `id`: row.`id`,
    `year`: row.`year`,
    `name`: row.`name`,
    `height`: row.`height`,
    `weight`: row.`weight` 
});

LOAD CSV WITH HEADERS FROM 'file:///rating.csv' AS row
MERGE (n:Rating {year: row.year,
    ranking: row.ranking,
    stars: row.stars,
    rating: row.rating}) 
WITH row, n 
MATCH(p:Player {id: row.id}) 
MERGE (p)-[:HAS_RATING]->(n)

LOAD CSV WITH HEADERS FROM 'file:///hometown.csv' AS row
MERGE (n:Hometown {city: row.city,
    hometown_fips: row.hometown_fips,
    county: row.county,
    state: row.state,
    hometown_lat: row.hometown_lat,
    hometown_long: row.hometown_long}) 
WITH row, n 
MATCH(p:Player {id: row.id}) 
MERGE (p)<-[:IS_FROM]-(n)

LOAD CSV WITH HEADERS FROM 'file:///college.csv' AS row
MERGE (n:College {name: row.college_commit}) 
WITH row, n 
MATCH(p:Player {id: row.id}) 
MERGE (p)<-[:COMMITTED_TO]-(n)

LOAD CSV WITH HEADERS FROM 'file:///school.csv' AS row
MERGE (n:School {name: row.school}) 
WITH row, n 
MATCH(p:Player {id: row.id}) 
MERGE (p)<-[:PLAYED_AT]-(n)

LOAD CSV WITH HEADERS FROM 'file:///position.csv' AS row 
MERGE (n:Position {name: row.position}) 
WITH row, n 
MATCH(p:Player {id: row.id}) 
MERGE (p)-[:HAS_POSITION]->(n);
# Out:
#   File "<ipython-input-69-06b834418779>", line 1
#     CREATE CONSTRAINT ON (n:Player) ASSERT n.id is UNIQUE;
#            ^
# SyntaxError: invalid syntax

# %%
//Create Players
LOAD CSV WITH HEADERS FROM 'file:///player.csv' AS row
CREATE(:Player
{
    `id`: row.`id`,
    `year`: row.`year`,
    `name`: row.`name`,
    `height`: row.`height`,
    `weight`: row.`weight` 
});

# %%
//Creating Rating
LOAD CSV WITH HEADERS FROM 'file:///rating.csv' AS row
MERGE (n:Rating {year: row.year,
    ranking: row.ranking,
    stars: row.stars,
    rating: row.rating}) 
WITH row, n 
MATCH(p:Player {id: row.id}) 
MERGE (p)-[:HAS_RATING]->(n)

# %%
//Create Hometown
LOAD CSV WITH HEADERS FROM 'file:///hometown.csv' AS row
MERGE (n:Hometown {name: row.city,
    hometown_fips: row.hometown_fips,
    county: row.county,
    state: row.state,
    hometown_lat: row.hometown_lat,
    hometown_long: row.hometown_long}) 
WITH row, n 
MATCH(p:Player {id: row.id}) 
MERGE (p)<-[:IS_FROM]-(n)

# %%
//Create College 
LOAD CSV WITH HEADERS FROM 'file:///collegeV2.csv' AS row
MERGE (n:College {name: row.college_commit,
                 conference: row.conference,
                 division: row.division,
                 college_state: row.college_state,
                 college_lat: row.college_lat,
                 college_long: row.college_long}) 
WITH row, n 
MATCH(p:Player {id: row.id}) 
MERGE (p)<-[:COMMITTED_TO]-(n)

# %%
//Create School
LOAD CSV WITH HEADERS FROM 'file:///school.csv' AS row
MERGE (n:School {name: row.school}) 
WITH row, n 
MATCH(p:Player {id: row.id}) 
MERGE (p)<-[:PLAYED_AT]-(n)

# %%
//Create Position
LOAD CSV WITH HEADERS FROM 'file:///positionV2.csv' AS row 
MERGE (n:Position {position: row.position,
                  position_name: row.position_name,
                  position_group: row.position_group,
                  type: row.type}) 
WITH row, n 
MATCH(p:Player {id: row.id}) 
MERGE (p)-[:HAS_POSITION]->(n);

# %%
MATCH (n:Hometown{city:'Charlotte'})
CALL gds.alpha.spanningTree.minimum.write({
  startNodeId: id(n),
  nodeProjection: 'Hometown',
  relationshipProjection: {
    COST: {
      type: 'COST',
      properties: 'distance',
      orientation: 'UNDIRECTED'
    }
  },
  relationshipWeightProperty: 'distance',
  writeProperty: 'MINST',
  weightWriteProperty: 'cost'
})
YIELD createMillis, computeMillis, writeMillis, effectiveNodeCount
RETURN createMillis, computeMillis, writeMillis, effectiveNodeCount;

# %%
MATCH path = (t:Rating)-[:TARGET_LOCATED]->(n:Hometown {city: 'Charlotte'})-[:MINST*]-()
WHERE t.year = '2021' AND ('0.78' < t.rating < '0.84')
WITH relationships(path) AS rels
UNWIND rels AS rel
WITH DISTINCT rel AS rel
WHERE rel.cost IS NOT NULL
RETURN startNode(rel).city AS source, endNode(rel).city AS destination, rel.cost AS cost

# %%
MATCH (c:College)-[:COMMITTED_TO]->(n:Player)
WITH n, c 
MATCH (c:College)-[:COMMITTED_TO]->(n)<-[:IS_FROM]-(h:Hometown)
CREATE (c)-[r:HAS_PIPELINE {name: c.name}]->(h)
RETURN type(r), r.name

# %%
MATCH (c:College)-[:COMMITTED_TO]->(n:Player)
WITH n, c 
MATCH (c:College)-[:COMMITTED_TO]->(n)<-[:IS_FROM]-(h:Hometown)
WITH count(n) as e, c, h
CREATE (c)-[r:HAS_PIPELINE]->(h)
SET r.frequency = e
RETURN type(r), r.frequency

# %%
MATCH (c1:College)-[r:HAS_PIPELINE]->(h:Hometown)<-[:HAS_PIPELINE]-(c2:College)
WITH c1, c2, count(r) as Cnt
WHERE c1.name <> 'Uncommitted' AND c2.name <> 'Uncommitted'
CREATE (c1)-[r:SHARES_TERRITORY]->(c2)
SET r.city_count = Cnt
RETURN type(r), r.city_count
